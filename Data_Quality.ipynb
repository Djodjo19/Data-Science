# %%
import pandas as pd

df1 = pd.read_csv('/home/depinfo/Bureau/jobs.csv', sep=';' )

df1.head(10)
# Out:
#        Job #  Doc #    Borough House #     Street Name  Block  Lot    Bin #  \
# 0  321291945      1   BROOKLYN    1473       44 STREET   5606   49  3136261
# 1  123370921      1  MANHATTAN      36     E. 3 STREET    458   25  1006549
# 2  421685439      1     QUEENS   34-56      200 STREET   6078   31  4619372
# 3  340644128      1   BROOKLYN     354  DOUGLAS STREET    946   15  3019327
# 4  421677974      2     QUEENS   35-37     36TH STREET    640    4  4009599
# 5  140815937      1  MANHATTAN     425    EAST 58TH ST   1370   15  1040637
# 6  123489386      2  MANHATTAN     341  WEST 44 STREET   1035   11  1024988
# 7  401995766      1     QUEENS  100-16      201 STREET  10867   15  4232322
# 8  321077696      1   BROOKLYN      60        HENRY ST    221   20  3001646
# 9  123547037      1  MANHATTAN     811     10TH AVENUE   1082   25  1027056
#
#   Job Type Job Status  ... SPECIAL_ACTION_STATUS SPECIAL_ACTION_DATE  \
# ...

# %%
df2 = pd.read_csv('/home/depinfo/Bureau/test.csv', sep=',')
df2.head(8)
# Out:
#    id    name  salary  start_date        dept
# 0   1    Rick  623.30  2012-01-01          IT
# 1   2     Dan  515.20  2013-09-23  Operations
# 2   3   Tusar  611.00  2014-11-15          IT
# 3   4    Ryan  729.00  2014-05-11          HR
# 4   5    Gary  843.25  2015-03-27     Finance
# 5   6   Rasmi  578.00  2013-05-21          IT
# 6   7  Pranab  632.80  2013-07-30  Operations
# 7   8    Guru  722.50  2014-06-17     Finance

# %%
print("The first dataset contain : ",df1.shape)
print("The second dataset contain : ",df2.shape)
# Out:
# The first dataset contain :  (91, 96)
# The second dataset contain :  (8, 5)

# %%
#drop all missing values :  we consider column as bad when 80% of it values are missing,so we have 96 and 
#we compute 80% of 96(in this case), with the parameter thresh, we specifythat beyond (len(df1))* 0.8 Of NaN, we drop the column 

a= (len(df1))* 0.8
df3 = df1.dropna(axis='columns', thresh=a)
#91 rows × 65 columns is the dimension of the new dataset with the good columns 
df3 
#save the new dataset in a csv file 
#df3.to_csv('NewDSwithoutMissingVal.csv')
df3
# Out:
#         Job #  Doc #    Borough House #     Street Name  Block   Lot    Bin #  \
# 0   321291945      1   BROOKLYN    1473       44 STREET   5606    49  3136261
# 1   123370921      1  MANHATTAN      36     E. 3 STREET    458    25  1006549
# 2   421685439      1     QUEENS   34-56      200 STREET   6078    31  4619372
# 3   340644128      1   BROOKLYN     354  DOUGLAS STREET    946    15  3019327
# 4   421677974      2     QUEENS   35-37     36TH STREET    640     4  4009599
# ..        ...    ...        ...     ...             ...    ...   ...      ...
# 86  340644734      1   BROOKLYN    1454   MYRTLE AVENUE   3308    22  3075691
# 87  140816491      1  MANHATTAN     277     PARK AVENUE   1302  7501  1076268
# 88  440520688      1     QUEENS  162-11     85TH STREET  14059    38  4294081
# 89  440520651      1     QUEENS  239-06        147 ROAD  13739    51  4291645
# 90  240236357      1      BRONX    1836   WATSON AVENUE   3730     1  2092810
#
# ...

# %%
df3['GIS_LATITUDE'].plot(kind='hist', rot=70, logx=True, logy=True, color='pink')

# %%
import numpy as np
import pandas as pd

df2.dtypes.value_counts()
# Out:
# object     3
# int64      1
# float64    1
# dtype: int64

# %%
df2.loc[2015:, 'start_date'].head(4)
# Out:
# Series([], Name: start_date, dtype: object)

# %%
# r'^(\d{4})': The regular expression is meant to find any four digits at the beginning of a string, the purpose 
# here is to be able to convert these dates into numerical data

extr = df2['start_date'].str.extract(r'^(\d{4})', expand=False)
extr.head(8)
# Out:
# 0    2012
# 1    2013
# 2    2014
# 3    2014
# 4    2015
# 5    2013
# 6    2013
# 7    2014
# Name: start_date, dtype: object

# %%
# this output column still has object dtype, but we can easily get its numerical using pd.to_numeric
df2['start_date'] = pd.to_numeric(extr)
df2['start_date'].dtype
# Out:
# dtype('int64')

# %%
df2['start_date'] = pd.to_datetime(df2['start_date'])
df2['start_date'] = df2['start_date'].apply(lambda x: x.date())
df2['start_date'].dtype
# Out:
# dtype('O')
